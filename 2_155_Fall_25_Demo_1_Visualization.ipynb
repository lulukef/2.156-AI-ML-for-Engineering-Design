# %% [markdown]
# <a href="https://colab.research.google.com/github/lulukef/2.156-AI-ML-for-Engineering-Design/blob/main/2_155_Fall_25_Demo_1_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualization Demo for Bikes
#
# <div style="font-size: small;">
# License Terms:
# These Python demos are licensed under a <a href="https://creativecommons.org/licenses/by-nc-nd/4.0/">Creative Commons Attribution-NonCommercial-NoDerivatives 4.0 International License</a>. They are intended for educational use only in Class 2.155/2.156: AI and ML for Engineering Design at MIT. You may not share or distribute them publicly, use them for commercial purposes, or provide them to industry or other entities without permission from the instructor (faez@mit.edu).
# </div>

# %% [markdown]
# # Hey there, future engineers! 🚴 Ever debated with your pals about MTBs vs. Road bikes for your weekend rides? Well, let's dive into some data and see how these two compare in the real world. Ready to pedal into this fun journey with numbers and insights? Let's roll!
#
#
# ![road+vs+mtb+pic.jpeg](data:image/jpeg;base64,...)
#
# Image source: https://pedalchile.com/blog/road-vs-mtb

# %% [markdown]
# **Why Data Visualization is Essential:**
#
# **Makes Complex Data Digestible:** Instead of sifting through spreadsheets, visuals simplify complex data sets.
#
#
# *   Quicker Insights: Spotting trends, patterns, or outliers becomes a breeze.
# *   Informed Decisions: Helps in making well-informed, data-driven decisions.
# *   Engages Audience: A good graph can convey a point more effectively than paragraphs of text.
# *   Memory Retention: Our brains process visuals faster and remember them longer.
#
#
#
#
#
#
#
#
# **Role of Specific Visualizations:**
#
# *   Scatterplots: Great for showing relationships between two variables. Wanna see if one thing goes up when another does? This is your plot!
# *   Histograms: Perfect for understanding the distribution of data. Curious about how many students scored in a particular grade range? Histograms show the spread!
# *   Box Plots (or Whisker Plots): Useful for spotting outliers and understanding data spread. They tell us about the median, quartiles, and possible outliers in one quick glance.
#
# Remember, the right visualization can make or break your data story. Choose wisely and happy plotting!

# %% [markdown]
# First we will import [Pandas](http://pandas.pydata.org/) (Python Data Analysis Library).

# %%
import pandas
import numpy as np

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %%
# Uncomment the below line if you want to see an example of the help function when you put '?' behind a function
#pandas.io.parsers.read_csv?

# %%
# Load the data
link = 'https://raw.githubusercontent.com/decode-mit/2s997demo/main/bike_data_2.csv'
#data = pandas.io.parsers.read_csv(link)

select_cols = [0, 1, 2, 3, 4, 5, 6, 7, 8]

data = pandas.io.parsers.read_csv(link, usecols=select_cols)

data
# Out:
#       Label  Seat tube length  Teeth on chainring 0  Wheel diameter front  \
# 0         1             588.7                    53                 689.0
# 1         1             460.0                    48                 623.0
# 2         2             535.0                    44                 670.0
# 3         2             520.0                    42                 699.0
# 4         2             457.0                    39                 745.0
# ...     ...               ...                   ...                   ...
# 2467      2             567.0                    42                 670.0
# 2468      2             380.0                    32                 710.0
# 2469      1             550.0                    53                 486.0
# 2470      1             550.0                    53                 486.0
# 2471      1             584.3                    53                 689.0
#
#       Saddle height  Stack  Seat tube diameter  Head tube length textfield  \
# ...

# %%
# Set column names
col_names = ['Label', 'Seat tube length', 'Teeth on chainring 0', 'Wheel diameter front', 'Saddle height', 'Stack','Seat tube diameter', 'Head tube length', 'Dropout spacing']
data.columns = [col_names[i] for i in select_cols]
data.head()
# Out:
#    Label  Seat tube length  Teeth on chainring 0  Wheel diameter front  \
# 0      1             588.7                    53                 689.0
# 1      1             460.0                    48                 623.0
# 2      2             535.0                    44                 670.0
# 3      2             520.0                    42                 699.0
# 4      2             457.0                    39                 745.0
#
#    Saddle height  Stack  Seat tube diameter  Head tube length  Dropout spacing
# 0          768.0  565.6                34.0             135.6            130.0
# 1          600.0  565.6                28.6              91.8            130.0
# 2          755.0  565.6                35.0             165.0            135.0
# 3          753.0  565.6                35.0             123.6            135.0
# 4          830.0  565.6                31.8             105.0            135.0

# %% [markdown]
# Running '%matplotlib inline' is a special command that allows you to render plots directly in the notebook and embed them in line with your code!

# %%
x = data[data.columns[1]]
y = data[data.columns[2]]

# %%
# Create a scatter plot
import matplotlib.pyplot as plt
plt.scatter(x,y,s=20)
plt.xlabel(data.columns[1])
plt.ylabel(data.columns[2])
plt.show()

# %%
# Another way to create a scatter plot
data.plot(kind='scatter', x=data.columns[1], y=data.columns[2])
plt.show()

# %%
# Let's add some color and adjust the size (s) and opacity (alpha)
data.plot(kind='scatter',x=data.columns[1],y=data.columns[2],
          c='Label',
          s=200, alpha=0.1)
plt.show()

# %%
# Remove the colorbar
data.plot(kind='scatter',x=data.columns[1],y=data.columns[2],
          c='Label', colorbar=False,
          s=50, alpha=0.75)
plt.show()

# %%
# Add a colormap
data.plot(kind='scatter',x=data.columns[1],y=data.columns[2], c='Label',
          s=50, colormap='Reds',colorbar=False, title='Bike type')
plt.show()

# %%
# Add a different colormap
data.plot(kind='scatter',x=data.columns[1],y=data.columns[2], c='Label',
          s=50, colormap='Set1',colorbar=False, title='Bike type')
plt.show()

# Read more about different colormaps here: https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
#Set global parameters for your figures text size

small_font = 8
medium_font = 12
large_font = 18

plt.rc('font', size = small_font)          # controls default text sizes
plt.rc('axes', titlesize = large_font)     # fontsize of the axes title
plt.rc('axes', labelsize = large_font)    # fontsize of the x and y labels
plt.rc('xtick', labelsize = medium_font)    # fontsize of the x tick labels
plt.rc('ytick', labelsize = medium_font)    # fontsize of the y tick labels

data.plot(kind='scatter',x=data.columns[1],y=data.columns[2], c='Label',
          s=50, colormap='Set1',colorbar=False, title='Bike type', zorder=1)

# You can also move things to the foreground or background using the zorder option

plt.plot([0,800],[0,60], zorder=2)
plt.show()

# %%
data.plot(kind='scatter',x=data.columns[1],y=data.columns[2], c='Label',
          s=50, colormap='Set1',colorbar=False, title='Bike type')

shadingx = np.linspace(200, 800, 100)

plt.gca().fill_between(shadingx, 20, 60, facecolor = 'yellow', edgecolors = 'black', alpha = 0.1)
plt.show()

# %% [markdown]
# Let's have some fun with plotting. Use different plot options to create an ugly scatterplot.

# %%
plt.rc('font', size = 12)          # controls default text sizes
plt.rc('axes', titlesize = 12)     # fontsize of the axes title
plt.rc('axes', labelsize = 12)    # fontsize of the x and y labels
plt.rc('xtick', labelsize = 12)    # fontsize of the x tick labels
plt.rc('ytick', labelsize = 12)    # fontsize of the y tick labels

data.plot(kind='scatter',x=data.columns[1],y=data.columns[2], c='Label',
          s=50, colormap='Set1',colorbar=False, title='Bike type')

plt.grid(axis = 'x', color = 'green', linestyle = '-', linewidth = 0.5)
plt.show()

# %%
# Ugly-fying the plot using GPT-4
plt.figure(figsize=(8, 5))
plt.scatter(x, y, c='#A17C6B', s=200, marker='2', alpha=0.5, edgecolors="yellow")
plt.title('The Ugliest Scatter Plot Ever?', fontsize=22, color='#05FFD2')
plt.xlabel('Seat Tube Length', fontsize=12, color='#FF5733')
plt.ylabel('Teeth on chainring 0', fontsize=12, color='#FF5733')
plt.grid(color='#F1C232', linestyle='--', linewidth=1)
plt.xticks(fontsize=10, rotation=45, color='#9146FF')
plt.yticks(fontsize=10, color='#9146FF')
plt.gca().set_facecolor('#D3D3D3')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-950321073.py:3: UserWarning: You passed a edgecolor/edgecolors ('yellow') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x, y, c='#A17C6B', s=200, marker='2', alpha=0.5, edgecolors="yellow")

# %% [markdown]
# [Bokeh](http://bokeh.pydata.org/en/latest/) is a different plotting utility (separate from Matplotlib) that also provides some plotting functionality. They have different pros/cons so try them out to determine which one works best for you.

# %%
from bokeh.plotting import figure, show, output_notebook
output_notebook()

# %%
p = figure(title = "Bike style")
p.xaxis.axis_label = data.columns[1]
p.yaxis.axis_label = data.columns[2]

p.circle(data[data.columns[1]], data[data.columns[2]], size=10)
show(p)
# Out:
# ...
#   <div id="a087db13-4b42-490a-928e-116fb491e0f4" data-root-id="p1003" style="display: contents;"></div>

# %%
p = figure(title = "Bike style")
p.xaxis.axis_label = data.columns[1]
p.yaxis.axis_label = data.columns[2]

p.circle(data[data.columns[1]], data[data.columns[2]],
         fill_alpha=0.2, size=10)
show(p)
# Out:
# ...
#   <div id="c4d885ab-b456-46cc-a25d-a0f26b36b6c8" data-root-id="p1049" style="display: contents;"></div>

# %% [markdown]
# The below line:
#
# ```python
# colors = [colormap[x] for x in data['Class label']]
# ```
#
# is a special type of python operation called a ["List Comprehension"](https://docs.python.org/2/tutorial/datastructures.html#list-comprehensions). I could also have written this in a more familiar way by writing:
#
# ```python
# colors = []
# for x in data['Class label']:
#    colors.append(colormap[x])
# ```

# %%
colormap = {1: '#73B6A1', 2: '#FC8E62'}
colors = [colormap[x] for x in data['Label']]

# %% [markdown]
# Red color shows Road bikes and Green shows Mountain bikes.

# %%
p = figure(title = "Bike style")
p.xaxis.axis_label = data.columns[1]
p.yaxis.axis_label = data.columns[2]

p.circle(data[data.columns[1]], data[data.columns[2]],
         color=colors, fill_alpha=0.2, size=10)
show(p)
# Out:
# ...
#   <div id="df09681e-f68b-43e1-8303-479788776e0c" data-root-id="p1095" style="display: contents;"></div>

# %% [markdown]
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures. Below we show some plotting examples using it.

# %%
import seaborn as sns
sns.histplot(data = data, x = data.columns[1], bins=50, kde = 'True', color='#73B6A1')
# Out:
# <Axes: xlabel='Seat tube length', ylabel='Count'>

# %%
sns.histplot(data= data, x=data.columns[2], bins=50, kde = 'True', color='#73B6A1')
# Out:
# <Axes: xlabel='Teeth on chainring 0', ylabel='Count'>

# %%
# Label 1 is Road, Label 2 is MTB. You can see that MTB has smaller seat tube length. MTB has larger dropout spacing and fewer teeth on chainring.
g = sns.FacetGrid(data, col="Label")
g.map(sns.scatterplot,data.columns[1], data.columns[2], data=data, hue = 'Label', palette="Set2")
g.add_legend();

# %%
sns.pairplot(data, hue = 'Label', palette="Set2")
plt.show()
#plt.savefig('save_as_a_png.png')

# %%
sns.jointplot(x = 'Seat tube length', y = 'Saddle height', data = data, kind="kde", color="#73B6A1")

# %%
# We make violin plots to observe the distribution
# These plots use a kernel density estimator to show a smooth probability distribution
sns.violinplot(x = 'Label', y = 'Seat tube length', data = data, palette="Set2")
# Out:
# /tmp/ipython-input-3640724691.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Label', y = 'Seat tube length', data = data, palette="Set2")
# <Axes: xlabel='Label', ylabel='Seat tube length'>

# %%
# What do you observe when we plot the dropout spacing?
sns.violinplot(x = 'Label', y = 'Dropout spacing', data = data, palette="Set2")
# Out:
# /tmp/ipython-input-179634774.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Label', y = 'Dropout spacing', data = data, palette="Set2")
# <Axes: xlabel='Label', ylabel='Dropout spacing'>

# %% [markdown]
# ## **Boxplots**
#  Boxplots are a way to graphically depict numerical data using quartiles. It shows the minimum, maximum, first quartile, third quartile, and the median value. They are widely used in machine learning papers to report results. It can help you understand the center, spread, asymmetry, and outliers.

# %%
# We can also make boxplots.
plt.rcParams['figure.figsize'] = [5, 5]
fig, ax = plt.subplots(1,2)

sns.boxplot(x = 'Label', y = 'Seat tube length', data = data, palette="Set2", linewidth=2, ax=ax[0])
ax[0].set(xlabel='Bike type')
ax[0].set_xticklabels(['Road', 'MTB'])

sns.boxplot(x = 'Label', y = 'Dropout spacing', data = data, palette="Set2", linewidth=2, ax=ax[1])
ax[1].set(xlabel='Bike type')
ax[1].set_xticklabels(['Road', 'MTB'])
fig.tight_layout()
# Out:
# /tmp/ipython-input-2661832362.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Label', y = 'Seat tube length', data = data, palette="Set2", linewidth=2, ax=ax[0])
# /tmp/ipython-input-2661832362.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(['Road', 'MTB'])
# /tmp/ipython-input-2661832362.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Label', y = 'Dropout spacing', data = data, palette="Set2", linewidth=2, ax=ax[1])
# ...

# %% [markdown]
# ## Swarm Plot
# A unique visualization that showcases individual data points adjacently to box or violin plots. Unlike a typical scatter plot, the Swarm Plot ensures that data points don't overlap, offering a clearer view of the data's distribution and density. This makes it particularly useful when you want to understand the variation within categories, especially when combined with summary visuals like the box or violin plots.

# %%
"""Swarm Plot
Display points for individual data alongside box or violin plots."""
sns.swarmplot(x='Label', y='Seat tube length', data=data, palette="Set2")
plt.xlabel('Bike Type')
plt.xticks(ticks=[0, 1], labels=['Road', 'MTB'])
plt.title('Swarm plot of Seat tube length by Bike Type')
plt.show()
# Out:
# /tmp/ipython-input-3933587130.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='Label', y='Seat tube length', data=data, palette="Set2")
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 66.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 25.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 77.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.lmplot(x = 'Seat tube length', y = 'Saddle height', data = data, col = 'Label', hue = 'Label', palette = "Set2")

# %% [markdown]
# ## Parallel Coordinates:
# A visualization technique used to plot individual data points across many variables. Each variable gets its own vertical axis, and all the axes are parallel to each other. Data points are represented as lines that intersect each axis at the respective value for that variable. This method is especially useful for spotting patterns and correlations in multivariate data, allowing for a clearer understanding of complex data sets with many attributes.

# %%
# Parallel coordinates

plt.rcParams['figure.figsize'] = [15, 5]
pandas.plotting.parallel_coordinates(data, 'Label', color=('#73B6A1', '#FC8E62'))
plt.show()

# %% [markdown]
# ## Radviz (Radial Visualization)
# A technique where data points are plotted as points inside a circle. Each feature (or dimension) of the data is represented as an anchor on the circumference of the circle. Data points are then positioned within the circle based on the values of their features. Each feature pulls the data point towards its anchor, with the strength of the pull being proportional to the value of the feature. This visualization method is beneficial for understanding multi-dimensional data and spotting clusters or patterns among the data points.

# %%
#Radviz visualization
plt.rcParams['figure.figsize'] = [10, 10]
pandas.plotting.radviz(data, 'Label',  color=('#73B6A1', '#FC8E62'))
# Out:
# <Axes: >

# %% [markdown]
# ## Heatmap:
# A heatmap allows you to visualize dataset's correlation using color encoding. Darker shades represent stronger correlations. For the bike dataset, it helps us see how certain variables, like seat tube length or saddle height, might relate to each other.
#
# For our bike data, the heatmap can show which features (like saddle height, teeth on chainring, etc.) are closely related or have any pattern. This can be useful in designing bikes, as we may want to adjust certain features based on their relationship with others.

# %%
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Histogram
# A graphical representation used to depict the distribution of a dataset. It divides the data into bins, with the height of each bar corresponding to the frequency of data points within that bin. Histograms provide insights into the data's central tendency, variability, and shape of distribution. They're especially useful for identifying skewness, outliers, or any unusual patterns in a dataset.

# %%
"""Histogram:
Histograms show the distribution of a dataset. The height of each bar signifies the number of data points that fall into each bin.
In our bike example, if we plot a histogram for 'Seat tube length', we can see how many bikes have seat tube lengths within certain ranges. This can be useful for identifying common sizes or outlier sizes in our data.
"""
plt.hist(data['Seat tube length'], bins=30, color='#5A9', alpha=0.7)
plt.title('Distribution of Seat Tube Lengths')
plt.xlabel('Seat Tube Length')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# ## Kernel Density Estimation (KDE) Plot
# A visualization method that displays the probability distribution of a continuous variable. It smoothens the distribution and provides a clearer view of the data structure than a histogram. KDE plots can be thought of as a smoothed version of the histogram, with the aim to estimate the underlying probability density function of the data. They're beneficial for identifying peaks, modes, and distribution shape.

# %%
sns.kdeplot(data[data['Label'] == 1]['Seat tube length'], shade=True, label='Road', color='#73B6A1')
sns.kdeplot(data[data['Label'] == 2]['Seat tube length'], shade=True, label='MTB', color='#FC8E62')
plt.title('KDE of Seat tube length by Bike Type')
plt.xlabel('Seat tube length')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-2284744490.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['Label'] == 1]['Seat tube length'], shade=True, label='Road', color='#73B6A1')
# /tmp/ipython-input-2284744490.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['Label'] == 2]['Seat tube length'], shade=True, label='MTB', color='#FC8E62')

# %% [markdown]
# ## Bar Chart
# A visual representation used to display and compare the frequency, count, or other metrics (e.g., mean) for different categories. It's made up of bars, where the length of each bar denotes the value of the category it represents. Bar charts can be oriented horizontally or vertically and are great for comparing discrete data, spotting trends, or understanding category rankings.

# %%
"""Bar Chart:
Bar charts represent data in rectangular bars. The length of each bar is proportional to the values it represents.

For the bike dataset, imagine we had an additional column indicating the 'Brand' of each bike. Using a bar chart, we could easily see which brands have the most bikes in our dataset or compare any feature (like average seat tube length) across brands.
"""
# Here's a simple example with made-up data for illustration:
brands = ['Brand A', 'Brand B', 'Brand C', 'Brand D']
bike_counts = [50, 60, 35, 45]

plt.bar(brands, bike_counts, color=['#FF5733', '#33FF57', '#3357FF', '#FF33D6'])
plt.title('Number of Bikes by Brand')
plt.xlabel('Brands')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# ## Animation
# Diving into "Seat tube length"
# Plotly offers interactive visualizations that can make data exploration fun. Let's see how "Seat tube length" varies with other features of the bike.

# %%
#!pip install plotly
import plotly.express as px

fig = px.scatter(data, x="Seat tube length", y="Teeth on chainring 0", animation_frame="Label",
                 range_x=[min(data["Seat tube length"]), max(data["Seat tube length"])],
                 range_y=[min(data["Teeth on chainring 0"]), max(data["Teeth on chainring 0"])],
                 title="Seat tube length vs. Teeth on chainring 0 (animated by Label)")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###Demo Reflection Questions:
#
# 1.	Please describe and show your ugly figure in your video (~20s).
# 2.	Reflect on a recent plot you made for a project or research paper. Through your exploration with data visualization, can you think of some ways to improve those visualizations? Explain (~20s).
# 3.	Pick one of the visualizations in this demo to improve. Create the improved visualization, then explain in your video (~20s) why you think the modified version might be more effective.
#
# (remember to include any code that you wrote or modified in your video, or attach it for the submission)
